# %%
import pandas as pd

# %%
col_data= pd.read_csv("plotting.csv")

# %%
col_data.shape
# Out:
# (650, 20)

# %%
col_data.head()
# Out:
#    Rank                                   Name       City Code Public/Private  \
# 0     1                     Harvard University  Cambridge   MA        Private
# 1     2                    Stanford University   Stanford   CA        Private
# 2     3                        Yale University  New Haven   CT        Private
# 3     4  Massachusetts Institute of Technology  Cambridge   MA        Private
# 4     5                   Princeton University  Princeton   NJ        Private
#
#    Undergraduate Population  Student Population  Net Price  Average Grant Aid  \
# 0                     13844               31120    14327.0            49870.0
# 1                      8402               17534    13261.0            50134.0
# 2                      6483               12974    18627.0            50897.0
# 3                      4680               11466    20771.0            43248.0
# 4                      5659                8273     9327.0            48088.0
#
#    Total Annual Cost  Alumni Salary  Acceptance Rate  SAT Lower  SAT Upper  \
# 0              69600       146800.0              5.0     1460.0     1590.0
# 1              69109       145200.0              5.0     1390.0     1540.0
# 2              71290       138300.0              7.0     1460.0     1580.0
# 3              67430       155200.0              7.0     1490.0     1570.0
# 4              66150       139400.0              6.0     1430.0     1570.0
#
#    ACT Lower  ACT Upper            Website        lat         lon  \
# 0       32.0       35.0    www.harvard.edu  42.375100  -71.105616
# 1       32.0       35.0   www.stanford.edu  37.426541 -122.170293
# 2       32.0       35.0       www.yale.edu  41.308214  -72.925052
# 3       33.0       35.0    www.web.mit.edu  42.375100  -71.105616
# 4       31.0       35.0  www.princeton.edu  40.349274  -74.659296
#
#            State
# 0  Massachusetts
# 1     California
# 2    Connecticut
# 3  Massachusetts
# 4     New Jersey

# %%
col_data.dropna(inplace=True)

# %%
col_data=col_data.fillna("")

# %%
col_data.isnull().sum()
# Out:
# Rank                        0
# Name                        0
# City                        0
# Code                        0
# Public/Private              0
# Undergraduate Population    0
# Student Population          0
# Net Price                   0
# Average Grant Aid           0
# Total Annual Cost           0
# Alumni Salary               0
# Acceptance Rate             0
# SAT Lower                   0
# SAT Upper                   0
# ACT Lower                   0
# ACT Upper                   0
# Website                     0
# lat                         0
# lon                         0
# State                       0
# dtype: int64

# %%
col_data.shape
# Out:
# (523, 20)

# %%
import json
json_data=[]
temp_data={}
data=[]
dict_json={}
for index,row in col_data.iterrows():
    location_info={
        "lat":row["lat"],
        "lng":row["lon"],
        "state":row["State"]
    }
    salary_info={ 
        "mid_career_median_salary":row["Alumni Salary"],
        "rank":row["Rank"],
        "code":row["Code"]

    }
    score_info={
        "SAT Lower":row["SAT Lower"], 
        "SAT Upper":row["SAT Upper"], 
        
    }
    admissions_info={
        "students":row["Student Population"],
        "acceptance_rate":row["Acceptance Rate"], 
    }
    json_data.append({
        "location_info":location_info,
        "school":row["Name"],
        "link":row["Website"],
        "salary_info":salary_info,
        "score_info":score_info,
        "admissions_info":admissions_info
        
    })

# %%
json_data
# Out:
# [{'location_info': {'lat': 42.3750997,
#    'lng': -71.1056157,
#    'state': 'Massachusetts'},
#   'school': 'Harvard University',
#   'link': 'www.harvard.edu',
#   'salary_info': {'mid_career_median_salary': 146800.0,
#    'rank': 1,
#    'code': 'MA'},
#   'score_info': {'SAT Lower': 1460.0, 'SAT Upper': 1590.0},
#   'admissions_info': {'students': 31120, 'acceptance_rate': 5.0}},
#  {'location_info': {'lat': 37.4265407,
#    'lng': -122.1702926,
#    'state': 'California'},
#   'school': 'Stanford University',
#   'link': 'www.stanford.edu',
#   'salary_info': {'mid_career_median_salary': 145200.0,
#    'rank': 2,
#    'code': 'CA'},
#   'score_info': {'SAT Lower': 1390.0, 'SAT Upper': 1540.0},
#   'admissions_info': {'students': 17534, 'acceptance_rate': 5.0}},
#  {'location_info': {'lat': 41.3082138,
#    'lng': -72.92505179999998,
#    'state': 'Connecticut'},
#   'school': 'Yale University',
#   'link': 'www.yale.edu',
#   'salary_info': {'mid_career_median_salary': 138300.0,
#    'rank': 3,
#    'code': 'CT'},
#   'score_info': {'SAT Lower': 1460.0, 'SAT Upper': 1580.0},
#   'admissions_info': {'students': 12974, 'acceptance_rate': 7.0}},
#  {'location_info': {'lat': 42.3750997,
#    'lng': -71.1056157,
#    'state': 'Massachusetts'},
#   'school': 'Massachusetts Institute of Technology',
#   'link': 'www.web.mit.edu',
#   'salary_info': {'mid_career_median_salary': 155200.0,
#    'rank': 4,
#    'code': 'MA'},
#   'score_info': {'SAT Lower': 1490.0, 'SAT Upper': 1570.0},
#   'admissions_info': {'students': 11466, 'acceptance_rate': 7.0}},
#  {'location_info': {'lat': 40.3492744,
#    'lng': -74.6592958,
#    'state': 'New Jersey'},
#   'school': 'Princeton University',
#   'link': 'www.princeton.edu',
#   'salary_info': {'mid_career_median_salary': 139400.0,
#    'rank': 5,
#    'code': 'NJ'},
#   'score_info': {'SAT Lower': 1430.0, 'SAT Upper': 1570.0},
#   'admissions_info': {'students': 8273, 'acceptance_rate': 6.0}},
#  {'location_info': {'lat': 39.9527237,
#    'lng': -75.16352619999998,
#    'state': 'Pennsylvania'},
#   'school': 'University of Pennsylvania',
#   'link': 'www.upenn.edu',
#   'salary_info': {'mid_career_median_salary': 133900.0,
#    'rank': 6,
#    'code': 'PA'},
#   'score_info': {'SAT Lower': 1420.0, 'SAT Upper': 1560.0},
#   'admissions_info': {'students': 25367, 'acceptance_rate': 9.0}},
#  {'location_info': {'lat': 41.8239891,
#    'lng': -71.4128343,
#    'state': 'Rhode Island'},
#   'school': 'Brown University',
#   'link': 'www.brown.edu',
#   'salary_info': {'mid_career_median_salary': 127600.0,
#    'rank': 7,
#    'code': 'RI'},
#   'score_info': {'SAT Lower': 1405.0, 'SAT Upper': 1570.0},
#   'admissions_info': {'students': 10095, 'acceptance_rate': 8.0}},
#  {'location_info': {'lat': 34.14764520000001,
#    'lng': -118.1444779,
#    'state': 'California'},
#   'school': 'California Institute of Technology',
#   'link': 'www.caltech.edu',
#   'salary_info': {'mid_career_median_salary': 151600.0,
#    'rank': 8,
#    'code': 'CA'},
#   'score_info': {'SAT Lower': 1530.0, 'SAT Upper': 1590.0},
#   'admissions_info': {'students': 2238, 'acceptance_rate': 8.0}},
#  {'location_info': {'lat': 35.996653,
#    'lng': -78.90180529999998,
#    'state': 'North Carolina'},
#   'school': 'Duke University',
#   'link': 'www.duke.edu',
#   'salary_info': {'mid_career_median_salary': 132100.0,
#    'rank': 9,
#    'code': 'NC'},
#   'score_info': {'SAT Lower': 1380.0, 'SAT Upper': 1540.0},
#   'admissions_info': {'students': 16130, 'acceptance_rate': 10.0}},
#  {'location_info': {'lat': 43.703622,
#    'lng': -72.288666,
#    'state': 'New Hampshire'},
#   'school': 'Dartmouth College',
#   'link': 'www.dartmouth.edu',
#   'salary_info': {'mid_career_median_salary': 130900.0,
#    'rank': 10,
#    'code': 'NH'},
#   'score_info': {'SAT Lower': 1430.0, 'SAT Upper': 1560.0},
#   'admissions_info': {'students': 6509, 'acceptance_rate': 10.0}},
#  {'location_info': {'lat': 42.4396039,
#    'lng': -76.49680190000002,
#    'state': 'New York'},
#   'school': 'Cornell University',
#   'link': 'www.cornell.edu',
#   'salary_info': {'mid_career_median_salary': 128200.0,
#    'rank': 11,
#    'code': 'NY'},
#   'score_info': {'SAT Lower': 1390.0, 'SAT Upper': 1550.0},
#   'admissions_info': {'students': 23016, 'acceptance_rate': 13.0}},
#  {'location_info': {'lat': 34.0966764,
#    'lng': -117.7197785,
#    'state': 'California'},
#   'school': 'Pomona College',
#   'link': 'www.pomona.edu',
#   'salary_info': {'mid_career_median_salary': 117200.0,
#    'rank': 12,
#    'code': 'CA'},
#   'score_info': {'SAT Lower': 1370.0, 'SAT Upper': 1530.0},
#   'admissions_info': {'students': 1665, 'acceptance_rate': 8.0}},
#  {'location_info': {'lat': 37.8708393,
#    'lng': -122.2728639,
#    'state': 'California'},
#   'school': 'University of California, Berkeley',
#   'link': 'www.berkeley.edu',
#   'salary_info': {'mid_career_median_salary': 131800.0,
#    'rank': 13,
#    'code': 'CA'},
#   'score_info': {'SAT Lower': 1260.0, 'SAT Upper': 1480.0},
#   'admissions_info': {'students': 41891, 'acceptance_rate': 17.0}},
#  {'location_info': {'lat': 40.7127281,
#    'lng': -74.0060152,
#    'state': 'New York'},
#   'school': 'Columbia University',
#   'link': 'www.columbia.edu',
#   'salary_info': {'mid_career_median_salary': 126800.0,
#    'rank': 14,
#    'code': 'NY'},
#   'score_info': {'SAT Lower': 1410.0, 'SAT Upper': 1570.0},
#   'admissions_info': {'students': 30454, 'acceptance_rate': 7.0}},
#  {'location_info': {'lat': 38.8949924,
#    'lng': -77.0365581,
#    'state': 'District of Columbia'},
#   'school': 'Georgetown University',
#   'link': 'www.georgetown.edu',
#   'salary_info': {'mid_career_median_salary': 122200.0,
#    'rank': 15,
#    'code': 'DC'},
#   'score_info': {'SAT Lower': 1350.0, 'SAT Upper': 1520.0},
#   'admissions_info': {'students': 19005, 'acceptance_rate': 16.0}},
#  {'location_info': {'lat': 41.87556160000001,
#    'lng': -87.6244212,
#    'state': 'Illinois'},
#   'school': 'University of Chicago',
#   'link': 'www.uchicago.edu',
#   'salary_info': {'mid_career_median_salary': 114200.0,
#    'rank': 16,
#    'code': 'IL'},
#   'score_info': {'SAT Lower': 1480.0, 'SAT Upper': 1580.0},
#   'admissions_info': {'students': 16227, 'acceptance_rate': 9.0}},
#  {'location_info': {'lat': 42.0447388,
#    'lng': -87.6930459,
#    'state': 'Illinois'},
#   'school': 'Northwestern University',
#   'link': 'www.northwestern.edu',
#   'salary_info': {'mid_career_median_salary': 115400.0,
#    'rank': 17,
#    'code': 'IL'},
#   'score_info': {'SAT Lower': 1420.0, 'SAT Upper': 1560.0},
#   'admissions_info': {'students': 22008, 'acceptance_rate': 9.0}},
#  {'location_info': {'lat': 41.70456770000001,
#    'lng': -86.2382203,
#    'state': 'Indiana'},
#   'school': 'University of Notre Dame',
#   'link': 'www.nd.edu',
#   'salary_info': {'mid_career_median_salary': 130500.0,
#    'rank': 18,
#    'code': 'IN'},
#   'score_info': {'SAT Lower': 1370.0, 'SAT Upper': 1520.0},
#   'admissions_info': {'students': 12467, 'acceptance_rate': 19.0}},
#  {'location_info': {'lat': 42.6889156,
#    'lng': -73.2246057,
#    'state': 'Massachusetts'},
#   'school': 'Williams College',
#   'link': 'www.williams.edu',
#   'salary_info': {'mid_career_median_salary': 127500.0,
#    'rank': 19,
#    'code': 'MA'},
#   'score_info': {'SAT Lower': 1400.0, 'SAT Upper': 1570.0},
#   'admissions_info': {'students': 2227, 'acceptance_rate': 15.0}},
#  {'location_info': {'lat': 42.2681569,
#    'lng': -83.7312291,
#    'state': 'Michigan'},
#   'school': 'University of Michigan, Ann Arbor',
#   'link': 'www.umich.edu',
#   'salary_info': {'mid_career_median_salary': 112200.0,
#    'rank': 20,
#    'code': 'MI'},
#   'score_info': {'SAT Lower': 1330.0, 'SAT Upper': 1500.0},
#   'admissions_info': {'students': 46002, 'acceptance_rate': 27.0}},
#  {'location_info': {'lat': 29.7589382, 'lng': -95.3676974, 'state': 'Texas'},
#   'school': 'Rice University',
#   'link': 'www.rice.edu',
#   'salary_info': {'mid_career_median_salary': 129500.0,
#    'rank': 21,
#    'code': 'TX'},
#   'score_info': {'SAT Lower': 1490.0, 'SAT Upper': 1580.0},
#   'admissions_info': {'students': 7022, 'acceptance_rate': 16.0}},
#  {'location_info': {'lat': 39.2908816, 'lng': -76.610759, 'state': 'Maryland'},
#   'school': 'Johns Hopkins University',
#   'link': 'www.jhu.edu',
#   'salary_info': {'mid_career_median_salary': 117100.0,
#    'rank': 22,
#    'code': 'MD'},
#   'score_info': {'SAT Lower': 1450.0, 'SAT Upper': 1570.0},
#   'admissions_info': {'students': 25151, 'acceptance_rate': 13.0}},
#  {'location_info': {'lat': 34.0966764,
#    'lng': -117.7197785,
#    'state': 'California'},
#   'school': 'Harvey Mudd College',
#   'link': 'www.hmc.edu',
#   'salary_info': {'mid_career_median_salary': 158200.0,
#    'rank': 23,
#    'code': 'CA'},
#   'score_info': {'SAT Lower': 1470.0, 'SAT Upper': 1570.0},
#   'admissions_info': {'students': 861, 'acceptance_rate': 15.0}},
#  {'location_info': {'lat': 39.9020565,
#    'lng': -75.34991240000002,
#    'state': 'Pennsylvania'},
#   'school': 'Swarthmore College',
#   'link': 'www.swarthmore.edu',
#   'salary_info': {'mid_career_median_salary': 123200.0,
#    'rank': 25,
#    'code': 'PA'},
#   'score_info': {'SAT Lower': 1380.0, 'SAT Upper': 1540.0},
#   'admissions_info': {'students': 1630, 'acceptance_rate': 11.0}},
#  {'location_info': {'lat': 36.1622296,
#    'lng': -86.7743531,
#    'state': 'Tennessee'},
#   'school': 'Vanderbilt University',
#   'link': 'www.vanderbilt.edu',
#   'salary_info': {'mid_career_median_salary': 119100.0,
#    'rank': 27,
#    'code': 'TN'},
#   'score_info': {'SAT Lower': 1440.0, 'SAT Upper': 1570.0},
#   'admissions_info': {'students': 12592, 'acceptance_rate': 11.0}},
#  {'location_info': {'lat': 42.3685658,
#    'lng': -72.505714,
#    'state': 'Massachusetts'},
#   'school': 'Amherst College',
#   'link': 'www.amherst.edu',
#   'salary_info': {'mid_career_median_salary': 116500.0,
#    'rank': 28,
#    'code': 'MA'},
#   'score_info': {'SAT Lower': 1400.0, 'SAT Upper': 1560.0},
#   'admissions_info': {'students': 1945, 'acceptance_rate': 13.0}},
#  {'location_info': {'lat': 34.0966764,
#    'lng': -117.7197785,
#    'state': 'California'},
#   'school': 'Claremont McKenna College',
#   'link': 'www.claremontmckenna.edu',
#   'salary_info': {'mid_career_median_salary': 125400.0,
#    'rank': 29,
#    'code': 'CA'},
#   'score_info': {'SAT Lower': 1340.0, 'SAT Upper': 1510.0},
#   'admissions_info': {'students': 1364, 'acceptance_rate': 10.0}},
#  {'location_info': {'lat': 34.0536909,
#    'lng': -118.242766,
#    'state': 'California'},
#   'school': 'University of Southern California',
#   'link': 'www.usc.edu',
#   'salary_info': {'mid_career_median_salary': 120600.0,
#    'rank': 30,
#    'code': 'CA'},
#   'score_info': {'SAT Lower': 1300.0, 'SAT Upper': 1500.0},
#   'admissions_info': {'students': 45687, 'acceptance_rate': 16.0}},
#  {'location_info': {'lat': 38.6264178,
#    'lng': -90.1998378,
#    'state': 'Missouri'},
#   'school': 'Washington University in St. Louis',
#   'link': 'www.wustl.edu',
#   'salary_info': {'mid_career_median_salary': 114900.0,
#    'rank': 31,
#    'code': 'MO'},
#   'score_info': {'SAT Lower': 1470.0, 'SAT Upper': 1570.0},
#   'admissions_info': {'students': 15303, 'acceptance_rate': 16.0}},
#  {'location_info': {'lat': 38.029306, 'lng': -78.4766781, 'state': 'Virginia'},
#   'school': 'University of Virginia',
#   'link': 'www.virginia.edu',
#   'salary_info': {'mid_career_median_salary': 117500.0,
#    'rank': 33,
#    'code': 'VA'},
#   'score_info': {'SAT Lower': 1310.0, 'SAT Upper': 1500.0},
#   'admissions_info': {'students': 24360, 'acceptance_rate': 27.0}},
#  {'location_info': {'lat': 42.4184296,
#    'lng': -71.10616390000001,
#    'state': 'Massachusetts'},
#   'school': 'Tufts University',
#   'link': 'www.tufts.edu',
#   'salary_info': {'mid_career_median_salary': 118100.0,
#    'rank': 34,
#    'code': 'MA'},
#   'score_info': {'SAT Lower': 1410.0, 'SAT Upper': 1540.0},
#   'admissions_info': {'students': 11449, 'acceptance_rate': 15.0}},
#  {'location_info': {'lat': 40.7127281,
#    'lng': -74.0060152,
#    'state': 'New York'},
#   'school': 'New York University',
#   'link': 'www.nyu.edu',
#   'salary_info': {'mid_career_median_salary': 117700.0,
#    'rank': 35,
#    'code': 'NY'},
#   'score_info': {'SAT Lower': 1290.0, 'SAT Upper': 1490.0},
#   'admissions_info': {'students': 51123, 'acceptance_rate': 28.0}},
#  {'location_info': {'lat': 44.00727360000001,
#    'lng': -73.1633011,
#    'state': 'Vermont'},
#   'school': 'Middlebury College',
#   'link': 'www.middlebury.edu',
#   'salary_info': {'mid_career_median_salary': 109800.0,
#    'rank': 36,
#    'code': 'VT'},
#   'score_info': {'SAT Lower': 1320.0, 'SAT Upper': 1510.0},
#   'admissions_info': {'students': 3855, 'acceptance_rate': 17.0}},
#  {'location_info': {'lat': 40.4416941,
#    'lng': -79.99008609999998,
#    'state': 'Pennsylvania'},
#   'school': 'Carnegie Mellon University',
#   'link': 'www.cmu.edu',
#   'salary_info': {'mid_career_median_salary': 136100.0,
#    'rank': 37,
#    'code': 'PA'},
#   'score_info': {'SAT Lower': 1430.0, 'SAT Upper': 1560.0},
#   'admissions_info': {'students': 13869, 'acceptance_rate': 22.0}},
#  {'location_info': {'lat': 34.0536909,
#    'lng': -118.242766,
#    'state': 'California'},
#   'school': 'University of California, Los Angeles',
#   'link': 'www.ucla.edu',
#   'salary_info': {'mid_career_median_salary': 116100.0,
#    'rank': 38,
#    'code': 'CA'},
#   'score_info': {'SAT Lower': 1220.0, 'SAT Upper': 1450.0},
#   'admissions_info': {'students': 44027, 'acceptance_rate': 16.0}},
#  {'location_info': {'lat': 42.3306529,
#    'lng': -71.1661647,
#    'state': 'Massachusetts'},
#   'school': 'Boston College',
#   'link': 'www.bc.edu',
#   'salary_info': {'mid_career_median_salary': 115400.0,
#    'rank': 41,
#    'code': 'MA'},
#   'score_info': {'SAT Lower': 1320.0, 'SAT Upper': 1490.0},
#   'admissions_info': {'students': 14628, 'acceptance_rate': 32.0}},
#  {'location_info': {'lat': 37.7802145,
#    'lng': -79.44385150000002,
#    'state': 'Virginia'},
#   'school': 'Washington and Lee University',
#   'link': 'www.wlu.edu',
#   'salary_info': {'mid_career_median_salary': 123200.0,
#    'rank': 42,
#    'code': 'VA'},
#   'score_info': {'SAT Lower': 1350.0, 'SAT Upper': 1490.0},
#   'admissions_info': {'students': 2220, 'acceptance_rate': 22.0}},
#  {'location_info': {'lat': 42.2964859,
#    'lng': -71.2925571,
#    'state': 'Massachusetts'},
#   'school': 'Wellesley College',
#   'link': 'www.wellesley.edu',
#   'salary_info': {'mid_career_median_salary': 106200.0,
#    'rank': 44,
#    'code': 'MA'},
#   'score_info': {'SAT Lower': 1360.0, 'SAT Upper': 1530.0},
#   'admissions_info': {'students': 2688, 'acceptance_rate': 22.0}},
#  {'location_info': {'lat': 35.9131542,
#    'lng': -79.05578,
#    'state': 'North Carolina'},
#   'school': 'University of North Carolina, Chapel Hill',
#   'link': 'www.unc.edu',
#   'salary_info': {'mid_career_median_salary': 100800.0,
#    'rank': 45,
#    'code': 'NC'},
#   'score_info': {'SAT Lower': 1270.0, 'SAT Upper': 1460.0},
#   'admissions_info': {'students': 29911, 'acceptance_rate': 24.0}},
#  {'location_info': {'lat': 42.82687979999999,
#    'lng': -75.5444159,
#    'state': 'New York'},
#   'school': 'Colgate University',
#   'link': 'www.colgate.edu',
#   'salary_info': {'mid_career_median_salary': 130600.0,
#    'rank': 46,
#    'code': 'NY'},
#   'score_info': {'SAT Lower': 1310.0, 'SAT Upper': 1500.0},
#   'admissions_info': {'students': 3025, 'acceptance_rate': 28.0}},
#  {'location_info': {'lat': 37.2789211,
#    'lng': -76.69448609999998,
#    'state': 'Virginia'},
#   'school': 'College of William &amp; Mary',
#   'link': 'www.wm.edu',
#   'salary_info': {'mid_career_median_salary': 108900.0,
#    'rank': 47,
#    'code': 'VA'},
#   'score_info': {'SAT Lower': 1300.0, 'SAT Upper': 1480.0},
#   'admissions_info': {'students': 8740, 'acceptance_rate': 36.0}},
#  {'location_info': {'lat': 35.4992614,
#    'lng': -80.8485218,
#    'state': 'North Carolina'},
#   'school': 'Davidson College',
#   'link': 'www.davidson.edu',
#   'salary_info': {'mid_career_median_salary': 106900.0,
#    'rank': 48,
#    'code': 'NC'},
#   'score_info': {'SAT Lower': 1310.0, 'SAT Upper': 1470.0},
#   'admissions_info': {'students': 1959, 'acceptance_rate': 20.0}},
#  {'location_info': {'lat': 40.01316720000001,
#    'lng': -75.2943516,
#    'state': 'Pennsylvania'},
#   'school': 'Haverford College',
#   'link': 'www.haverford.edu',
#   'salary_info': {'mid_career_median_salary': 112300.0,
#    'rank': 49,
#    'code': 'PA'},
#   'score_info': {'SAT Lower': 1390.0, 'SAT Upper': 1530.0},
#   'admissions_info': {'students': 1326, 'acceptance_rate': 20.0}},
#  {'location_info': {'lat': 40.7127281,
#    'lng': -74.0060152,
#    'state': 'New York'},
#   'school': 'Barnard College',
#   'link': 'www.barnard.edu',
#   'salary_info': {'mid_career_median_salary': 109800.0,
#    'rank': 50,
#    'code': 'NY'},
#   'score_info': {'SAT Lower': 1310.0, 'SAT Upper': 1500.0},
#   'admissions_info': {'students': 2668, 'acceptance_rate': 15.0}},
#  {'location_info': {'lat': 37.2333253,
#    'lng': -121.68463490000002,
#    'state': 'California'},
#   'school': 'Santa Clara University',
#   'link': 'www.scu.edu',
#   'salary_info': {'mid_career_median_salary': 134700.0,
#    'rank': 51,
#    'code': 'CA'},
#   'score_info': {'SAT Lower': 1270.0, 'SAT Upper': 1440.0},
#   'admissions_info': {'students': 8629, 'acceptance_rate': 54.0}},
#  {'location_info': {'lat': 44.4582041,
#    'lng': -93.161159,
#    'state': 'Minnesota'},
#   'school': 'Carleton College',
#   'link': 'www.carleton.edu',
#   'salary_info': {'mid_career_median_salary': 109900.0,
#    'rank': 52,
#    'code': 'MN'},
#   'score_info': {'SAT Lower': 1360.0, 'SAT Upper': 1530.0},
#   'admissions_info': {'students': 2155, 'acceptance_rate': 21.0}},
#  {'location_info': {'lat': 33.7489924, 'lng': -84.3902644, 'state': 'Georgia'},
#   'school': 'Emory University',
#   'link': 'www.emory.edu',
#   'salary_info': {'mid_career_median_salary': 110800.0,
#    'rank': 55,
#    'code': 'GA'},
#   'score_info': {'SAT Lower': 1350.0, 'SAT Upper': 1520.0},
#   'admissions_info': {'students': 14263, 'acceptance_rate': 22.0}},
#  {'location_info': {'lat': 40.6916081,
#    'lng': -75.2099866,
#    'state': 'Pennsylvania'},
#   'school': 'Lafayette College',
#   'link': 'www.lafayette.edu',
#   'salary_info': {'mid_career_median_salary': 122500.0,
#    'rank': 57,
#    'code': 'PA'},
#   'score_info': {'SAT Lower': 1260.0, 'SAT Upper': 1440.0},
#   'admissions_info': {'students': 2594, 'acceptance_rate': 31.0}},
#  {'location_info': {'lat': 40.7127281,
#    'lng': -74.0060152,
#    'state': 'New York'},
#   'school': 'Cooper Union',
#   'link': 'www.cooper.edu',
#   'salary_info': {'mid_career_median_salary': 126200.0,
#    'rank': 58,
#    'code': 'NY'},
#   'score_info': {'SAT Lower': 1310.0, 'SAT Upper': 1530.0},
#   'admissions_info': {'students': 946, 'acceptance_rate': 13.0}},
#  {'location_info': {'lat': 43.0484029,
#    'lng': -75.37850340000001,
#    'state': 'New York'},
#   'school': 'Hamilton College',
#   'link': 'www.hamilton.edu/index.cfm',
#   'salary_info': {'mid_career_median_salary': 108100.0,
#    'rank': 59,
#    'code': 'NY'},
#   'score_info': {'SAT Lower': 1360.0, 'SAT Upper': 1510.0},
#   'admissions_info': {'students': 2043, 'acceptance_rate': 24.0}},
#  {'location_info': {'lat': 34.0966764,
#    'lng': -117.7197785,
#    'state': 'California'},
#   'school': 'Scripps College',
#   'link': 'www.scrippscollege.edu',
#   'salary_info': {'mid_career_median_salary': 98600.0,
#    'rank': 60,
#    'code': 'CA'},
#   'score_info': {'SAT Lower': 1290.0, 'SAT Upper': 1460.0},
#   'admissions_info': {'students': 1092, 'acceptance_rate': 33.0}},
#  {'location_info': {'lat': 41.7065539,
#    'lng': -73.9283672,
#    'state': 'New York'},
#   'school': 'Vassar College',
#   'link': 'www.vassar.edu',
#   'salary_info': {'mid_career_median_salary': 100100.0,
#    'rank': 61,
#    'code': 'NY'},
#   'score_info': {'SAT Lower': 1330.0, 'SAT Upper': 1500.0},
#   'admissions_info': {'students': 2572, 'acceptance_rate': 24.0}},
#  {'location_info': {'lat': 42.2970161,
#    'lng': -71.25505009999998,
#    'state': 'Massachusetts'},
#   'school': 'Babson College',
#   'link': 'www.babson.edu',
#   'salary_info': {'mid_career_median_salary': 133800.0,
#    'rank': 62,
#    'code': 'MA'},
#   'score_info': {'SAT Lower': 1230.0, 'SAT Upper': 1410.0},
#   'admissions_info': {'students': 3329, 'acceptance_rate': 24.0}},
#  {'location_info': {'lat': 38.980666, 'lng': -76.9369189, 'state': 'Maryland'},
#   'school': 'University of Maryland, College Park',
#   'link': 'www.umd.edu',
#   'salary_info': {'mid_career_median_salary': 113400.0,
#    'rank': 63,
#    'code': 'MD'},
#   'score_info': {'SAT Lower': 1280.0, 'SAT Upper': 1470.0},
#   'admissions_info': {'students': 40521, 'acceptance_rate': 45.0}},
#  {'location_info': {'lat': 47.6038321,
#    'lng': -122.3300624,
#    'state': 'Washington'},
#   'school': 'University of Washington, Seattle',
#   'link': 'www.uw.edu',
#   'salary_info': {'mid_career_median_salary': 112300.0,
#    'rank': 64,
#    'code': 'WA'},
#   'score_info': {'SAT Lower': 1190.0, 'SAT Upper': 1420.0},
#   'admissions_info': {'students': 46166, 'acceptance_rate': 46.0}},
#  {'location_info': {'lat': 33.7489924, 'lng': -84.3902644, 'state': 'Georgia'},
#   'school': 'Georgia Institute of Technology',
#   'link': 'www.gatech.edu',
#   'salary_info': {'mid_career_median_salary': 133400.0,
#    'rank': 65,
#    'code': 'GA'},
#   'score_info': {'SAT Lower': 1090.0, 'SAT Upper': 1520.0},
#   'admissions_info': {'students': 29376, 'acceptance_rate': 23.0}},
#  {'location_info': {'lat': 40.8197448,
#    'lng': -73.7349567,
#    'state': 'New York'},
#   'school': 'United States Merchant Marine Academy',
#   'link': 'www.usmma.edu',
#   'salary_info': {'mid_career_median_salary': 140700.0,
#    'rank': 66,
#    'code': 'NY'},
#   'score_info': {'SAT Lower': 1210.0, 'SAT Upper': 1280.0},
#   'admissions_info': {'students': 975, 'acceptance_rate': 22.0}},
#  {'location_info': {'lat': 40.6178915,
#    'lng': -75.3786521,
#    'state': 'Pennsylvania'},
#   'school': 'Lehigh University',
#   'link': 'www4.lehigh.edu/default.aspx',
#   'salary_info': {'mid_career_median_salary': 134100.0,
#    'rank': 67,
#    'code': 'PA'},
#   'score_info': {'SAT Lower': 1270.0, 'SAT Upper': 1430.0},
#   'admissions_info': {'students': 7017, 'acceptance_rate': 25.0}},
#  {'location_info': {'lat': 40.1164205,
#    'lng': -88.2433829,
#    'state': 'Illinois'},
#   'school': 'University of Illinois, Urbana-Champaign',
#   'link': 'www.illinois.edu',
#   'salary_info': {'mid_career_median_salary': 115300.0,
#    'rank': 68,
#    'code': 'IL'},
#   'score_info': {'SAT Lower': 1340.0, 'SAT Upper': 1500.0},
#   'admissions_info': {'students': 48216, 'acceptance_rate': 62.0}},
#  {'location_info': {'lat': 43.074761,
#    'lng': -89.3837613,
#    'state': 'Wisconsin'},
#   'school': 'University of Wisconsin, Madison',
#   'link': 'www.wisc.edu',
#   'salary_info': {'mid_career_median_salary': 104400.0,
#    'rank': 69,
#    'code': 'WI'},
#   'score_info': {'SAT Lower': 1280.0, 'SAT Upper': 1450.0},
#   'admissions_info': {'students': 42977, 'acceptance_rate': 54.0}},
#  {'location_info': {'lat': 29.6519684, 'lng': -82.3249846, 'state': 'Florida'},
#   'school': 'University of Florida',
#   'link': 'www.ufl.edu',
#   'salary_info': {'mid_career_median_salary': 102800.0,
#    'rank': 70,
#    'code': 'FL'},
#   'score_info': {'SAT Lower': 1240.0, 'SAT Upper': 1400.0},
#   'admissions_info': {'students': 52669, 'acceptance_rate': 42.0}},
#  {'location_info': {'lat': 40.375643, 'lng': -82.3970994, 'state': 'Ohio'},
#   'school': 'Kenyon College',
#   'link': 'www.kenyon.edu/index.xml',
#   'salary_info': {'mid_career_median_salary': 103800.0,
#    'rank': 71,
#    'code': 'OH'},
#   'score_info': {'SAT Lower': 1263.0, 'SAT Upper': 1460.0},
#   'admissions_info': {'students': 1795, 'acceptance_rate': 34.0}},
#  {'location_info': {'lat': 40.0373323,
#    'lng': -75.34907690000001,
#    'state': 'Pennsylvania'},
#   'school': 'Villanova University',
#   'link': 'www.villanova.edu',
#   'salary_info': {'mid_career_median_salary': 119500.0,
#    'rank': 72,
#    'code': 'PA'},
#   'score_info': {'SAT Lower': 1250.0, 'SAT Upper': 1440.0},
#   'admissions_info': {'students': 10967, 'acceptance_rate': 36.0}},
#  {'location_info': {'lat': 40.9645293,
#    'lng': -76.8844101,
#    'state': 'Pennsylvania'},
#   'school': 'Bucknell University',
#   'link': 'www.bucknell.edu',
#   'salary_info': {'mid_career_median_salary': 122900.0,
#    'rank': 73,
#    'code': 'PA'},
#   'score_info': {'SAT Lower': 1250.0, 'SAT Upper': 1420.0},
#   'admissions_info': {'students': 3740, 'acceptance_rate': 31.0}},
#  {'location_info': {'lat': 42.3602534,
#    'lng': -71.0582912,
#    'state': 'Massachusetts'},
#   'school': 'Boston University',
#   'link': 'www.bu.edu',
#   'salary_info': {'mid_career_median_salary': 113600.0,
#    'rank': 74,
#    'code': 'MA'},
#   'score_info': {'SAT Lower': 1300.0, 'SAT Upper': 1480.0},
#   'admissions_info': {'students': 33355, 'acceptance_rate': 25.0}},
#  {'location_info': {'lat': 44.5520105,
#    'lng': -69.63171209999999,
#    'state': 'Maine'},
#   'school': 'Colby College',
#   'link': 'www.colby.edu',
#   'salary_info': {'mid_career_median_salary': 103300.0,
#    'rank': 75,
#    'code': 'ME'},
#   'score_info': {'SAT Lower': 1340.0, 'SAT Upper': 1500.0},
#   'admissions_info': {'students': 2032, 'acceptance_rate': 16.0}},
#  {'location_info': {'lat': 30.2711286, 'lng': -97.7436995, 'state': 'Texas'},
#   'school': 'University of Texas, Austin',
#   'link': 'www.utexas.edu',
#   'salary_info': {'mid_career_median_salary': 112800.0,
#    'rank': 76,
#    'code': 'TX'},
#   'score_info': {'SAT Lower': 1220.0, 'SAT Upper': 1460.0},
#   'admissions_info': {'students': 51525, 'acceptance_rate': 36.0}},
#  {'location_info': {'lat': 38.8949924,
#    'lng': -77.0365581,
#    'state': 'District of Columbia'},
#   'school': 'George Washington University',
#   'link': 'www.gwu.edu',
#   'salary_info': {'mid_career_median_salary': 115300.0,
#    'rank': 78,
#    'code': 'DC'},
#   'score_info': {'SAT Lower': 1280.0, 'SAT Upper': 1440.0},
#   'admissions_info': {'students': 27973, 'acceptance_rate': 41.0}},
#  {'location_info': {'lat': 32.7174202,
#    'lng': -117.16277279999998,
#    'state': 'California'},
#   'school': 'University of California, San Diego',
#   'link': 'www.ucsd.edu',
#   'salary_info': {'mid_career_median_salary': 123700.0,
#    'rank': 79,
#    'code': 'CA'},
#   'score_info': {'SAT Lower': 1210.0, 'SAT Upper': 1410.0},
#   'admissions_info': {'students': 35772, 'acceptance_rate': 34.0}},
#  {'location_info': {'lat': 41.7430554, 'lng': -92.7224206, 'state': 'Iowa'},
#   'school': 'Grinnell College',
#   'link': 'www.grinnell.edu',
#   'salary_info': {'mid_career_median_salary': 96500.0,
#    'rank': 80,
#    'code': 'IA'},
#   'score_info': {'SAT Lower': 1310.0, 'SAT Upper': 1510.0},
#   'admissions_info': {'students': 1765, 'acceptance_rate': 29.0}},
#  {'location_info': {'lat': 43.157285, 'lng': -77.615214, 'state': 'New York'},
#   'school': 'University of Rochester',
#   'link': 'www.rochester.edu',
#   'salary_info': {'mid_career_median_salary': 112700.0,
#    'rank': 82,
#    'code': 'NY'},
#   'score_info': {'SAT Lower': 1300.0, 'SAT Upper': 1490.0},
#   'admissions_info': {'students': 11648, 'acceptance_rate': 34.0}},
#  {'location_info': {'lat': 37.53850870000001,
#    'lng': -77.43428,
#    'state': 'Virginia'},
#   'school': 'University of Richmond',
#   'link': 'www.richmond.edu',
#   'salary_info': {'mid_career_median_salary': 107500.0,
#    'rank': 83,
#    'code': 'VA'},
#   'score_info': {'SAT Lower': 1270.0, 'SAT Upper': 1460.0},
#   'admissions_info': {'students': 4023, 'acceptance_rate': 33.0}},
#  {'location_info': {'lat': 34.4221319,
#    'lng': -119.7026673,
#    'state': 'California'},
#   'school': 'University of California, Santa Barbara',
#   'link': 'www.ucsb.edu',
#   'salary_info': {'mid_career_median_salary': 116300.0,
#    'rank': 84,
#    'code': 'CA'},
#   'score_info': {'SAT Lower': 1190.0, 'SAT Upper': 1400.0},
#   'admissions_info': {'students': 25057, 'acceptance_rate': 33.0}},
#  {'location_info': {'lat': 41.2939386,
#    'lng': -82.21737859999998,
#    'state': 'Ohio'},
#   'school': 'Oberlin College',
#   'link': 'www.oberlin.edu',
#   'salary_info': {'mid_career_median_salary': 96800.0,
#    'rank': 85,
#    'code': 'OH'},
#   'score_info': {'SAT Lower': 1280.0, 'SAT Upper': 1450.0},
#   'admissions_info': {'students': 3030, 'acceptance_rate': 34.0}},
#  {'location_info': {'lat': 44.9504037,
#    'lng': -93.1015026,
#    'state': 'Minnesota'},
#   'school': 'Macalester College',
#   'link': 'www.macalester.edu',
#   'salary_info': {'mid_career_median_salary': 100400.0,
#    'rank': 86,
#    'code': 'MN'},
#   'score_info': {'SAT Lower': 1300.0, 'SAT Upper': 1480.0},
#   'admissions_info': {'students': 2249, 'acceptance_rate': 41.0}},
#  {'location_info': {'lat': 33.6856969,
#    'lng': -117.82598190000002,
#    'state': 'California'},
#   'school': 'University of California, Irvine',
#   'link': 'www.uci.edu',
#   'salary_info': {'mid_career_median_salary': 116000.0,
#    'rank': 87,
#    'code': 'CA'},
#   'score_info': {'SAT Lower': 1170.0, 'SAT Upper': 1350.0},
#   'admissions_info': {'students': 35242, 'acceptance_rate': 37.0}},
#  {'location_info': {'lat': 38.545379,
#    'lng': -121.7445835,
#    'state': 'California'},
#   'school': 'University of California, Davis',
#   'link': 'www.ucdavis.edu',
#   'salary_info': {'mid_career_median_salary': 112600.0,
#    'rank': 88,
#    'code': 'CA'},
#   'score_info': {'SAT Lower': 1130.0, 'SAT Upper': 1360.0},
#   'admissions_info': {'students': 37380, 'acceptance_rate': 43.0}},
#  {'location_info': {'lat': 46.0667277,
#    'lng': -118.3393456,
#    'state': 'Washington'},
#   'school': 'Whitman College',
#   'link': 'www.whitman.edu',
#   'salary_info': {'mid_career_median_salary': 102600.0,
#    'rank': 89,
#    'code': 'WA'},
#   'score_info': {'SAT Lower': 1140.0, 'SAT Upper': 1380.0},
#   'admissions_info': {'students': 1574, 'acceptance_rate': 52.0}},
#  {'location_info': {'lat': 25.72149, 'lng': -80.2683838, 'state': 'Florida'},
#   'school': 'University of Miami (FL)',
#   'link': 'www.miami.edu',
#   'salary_info': {'mid_career_median_salary': 99600.0,
#    'rank': 90,
#    'code': 'FL'},
#   'score_info': {'SAT Lower': 1230.0, 'SAT Upper': 1420.0},
#   'admissions_info': {'students': 17003, 'acceptance_rate': 36.0}},
#  {'location_info': {'lat': 32.7762719, 'lng': -96.7968559, 'state': 'Texas'},
#   'school': 'Southern Methodist University',
#   'link': 'www.smu.edu',
#   'salary_info': {'mid_career_median_salary': 110400.0,
#    'rank': 91,
#    'code': 'TX'},
#   'score_info': {'SAT Lower': 1270.0, 'SAT Upper': 1440.0},
#   'admissions_info': {'students': 11789, 'acceptance_rate': 49.0}},
#  {'location_info': {'lat': 39.755543,
#    'lng': -105.2210997,
#    'state': 'Colorado'},
#   'school': 'Colorado School of Mines',
#   'link': 'www.mines.edu',
#   'salary_info': {'mid_career_median_salary': 139600.0,
#    'rank': 94,
#    'code': 'CO'},
#   'score_info': {'SAT Lower': 1310.0, 'SAT Upper': 1450.0},
#   'admissions_info': {'students': 6209, 'acceptance_rate': 56.0}},
#  {'location_info': {'lat': 40.2338438, 'lng': -111.6585337, 'state': 'Utah'},
#   'school': 'Brigham Young University',
#   'link': 'www.byu.edu',
#   'salary_info': {'mid_career_median_salary': 108000.0,
#    'rank': 95,
#    'code': 'UT'},
#   'score_info': {'SAT Lower': 1210.0, 'SAT Upper': 1410.0},
#   'admissions_info': {'students': 35807, 'acceptance_rate': 52.0}},
#  {'location_info': {'lat': 42.3756401,
#    'lng': -71.2358004,
#    'state': 'Massachusetts'},
#   'school': 'Brandeis University',
#   'link': 'www.brandeis.edu',
#   'salary_info': {'mid_career_median_salary': 113200.0,
#    'rank': 96,
#    'code': 'MA'},
#   'score_info': {'SAT Lower': 1280.0, 'SAT Upper': 1470.0},
#   'admissions_info': {'students': 5721, 'acceptance_rate': 34.0}},
#  {'location_info': {'lat': 40.7127281,
#    'lng': -74.0060152,
#    'state': 'New York'},
#   'school': 'Yeshiva University',
#   'link': 'www.yu.edu',
#   'salary_info': {'mid_career_median_salary': 112800.0,
#    'rank': 97,
#    'code': 'NY'},
#   'score_info': {'SAT Lower': 1160.0, 'SAT Upper': 1420.0},
#   'admissions_info': {'students': 6330, 'acceptance_rate': 63.0}},
#  {'location_info': {'lat': 44.9772995,
#    'lng': -93.2654692,
#    'state': 'Minnesota'},
#   'school': 'University of Minnesota, Twin Cities',
#   'link': 'www.umn.edu',
#   'salary_info': {'mid_career_median_salary': 104000.0,
#    'rank': 98,
#    'code': 'MN'},
#   'score_info': {'SAT Lower': 1270.0, 'SAT Upper': 1480.0},
#   'admissions_info': {'students': 51848, 'acceptance_rate': 50.0}},
#  {'location_info': {'lat': 33.9597677, 'lng': -83.376398, 'state': 'Georgia'},
#   'school': 'University of Georgia',
#   'link': 'www.uga.edu',
#   'salary_info': {'mid_career_median_salary': 100700.0,
#    'rank': 99,
#    'code': 'GA'},
#   'score_info': {'SAT Lower': 1200.0, 'SAT Upper': 1370.0},
#   'admissions_info': {'students': 37606, 'acceptance_rate': 54.0}},
#  {'location_info': {'lat': 41.5051613, 'lng': -81.6934446, 'state': 'Ohio'},
#   'school': 'Case Western Reserve University',
#   'link': 'www.case.edu',
#   'salary_info': {'mid_career_median_salary': 117800.0,
#    'rank': 100,
#    'code': 'OH'},
#   'score_info': {'SAT Lower': 1340.0, 'SAT Upper': 1520.0},
#   'admissions_info': {'students': 11824, 'acceptance_rate': 33.0}},
#  {'location_info': {'lat': 43.08217929999999,
#    'lng': -73.7853915,
#    'state': 'New York'},
#   'school': 'Skidmore College',
#   'link': 'www.skidmore.edu',
#   'salary_info': {'mid_career_median_salary': 99700.0,
#    'rank': 101,
#    'code': 'NY'},
#   'score_info': {'SAT Lower': 1205.0, 'SAT Upper': 1400.0},
#   'admissions_info': {'students': 2835, 'acceptance_rate': 25.0}},
#  {'location_info': {'lat': 34.0536909,
#    'lng': -118.242766,
#    'state': 'California'},
#   'school': 'Occidental College',
#   'link': 'www.oxy.edu',
#   'salary_info': {'mid_career_median_salary': 105700.0,
#    'rank': 102,
#    'code': 'CA'},
#   'score_info': {'SAT Lower': 1280.0, 'SAT Upper': 1440.0},
#   'admissions_info': {'students': 2123, 'acceptance_rate': 42.0}},
#  {'location_info': {'lat': 30.5955289, 'lng': -96.3071042, 'state': 'Texas'},
#   'school': 'Texas A&amp;M University, College Station',
#   'link': 'www.tamu.edu',
#   'salary_info': {'mid_career_median_salary': 115700.0,
#    'rank': 103,
#    'code': 'TX'},
#   'score_info': {'SAT Lower': 1140.0, 'SAT Upper': 1360.0},
#   'admissions_info': {'students': 67929, 'acceptance_rate': 71.0}},
#  {'location_info': {'lat': 45.5202471, 'lng': -122.6741949, 'state': 'Oregon'},
#   'school': 'Reed College',
#   'link': 'www.reed.edu',
#   'salary_info': {'mid_career_median_salary': 104900.0,
#    'rank': 105,
#    'code': 'OR'},
#   'score_info': {'SAT Lower': 1310.0, 'SAT Upper': 1500.0},
#   'admissions_info': {'students': 1490, 'acceptance_rate': 36.0}},
#  {'location_info': {'lat': 29.949932300000004,
#    'lng': -90.0701156,
#    'state': 'Louisiana'},
#   'school': 'Tulane University',
#   'link': 'www.tulane.edu',
#   'salary_info': {'mid_career_median_salary': 105300.0,
#    'rank': 106,
#    'code': 'LA'},
#   'score_info': {'SAT Lower': 1330.0, 'SAT Upper': 1490.0},
#   'admissions_info': {'students': 12384, 'acceptance_rate': 21.0}},
#  {'location_info': {'lat': 42.3756401,
#    'lng': -71.2358004,
#    'state': 'Massachusetts'},
#   'school': 'Bentley University',
#   'link': 'www.bentley.edu',
#   'salary_info': {'mid_career_median_salary': 116600.0,
#    'rank': 107,
#    'code': 'MA'},
#   'score_info': {'SAT Lower': 1210.0, 'SAT Upper': 1380.0},
#   'admissions_info': {'students': 5543, 'acceptance_rate': 44.0}},
#  {'location_info': {'lat': 37.2296566,
#    'lng': -80.4136767,
#    'state': 'Virginia'},
#   'school': 'Virginia Tech',
#   'link': 'www.vt.edu',
#   'salary_info': {'mid_career_median_salary': 114000.0,
#    'rank': 108,
#    'code': 'VA'},
#   'score_info': {'SAT Lower': 1180.0, 'SAT Upper': 1360.0},
#   'admissions_info': {'students': 34440, 'acceptance_rate': 70.0}},
#  {'location_info': {'lat': 41.764582,
#    'lng': -72.6908547,
#    'state': 'Connecticut'},
#   'school': 'Trinity College (CT)',
#   'link': 'www.trincoll.edu/Pages/default.aspx',
#   'salary_info': {'mid_career_median_salary': 110900.0,
#    'rank': 109,
#    'code': 'CT'},
#   'score_info': {'SAT Lower': 1260.0, 'SAT Upper': 1420.0},
#   'admissions_info': {'students': 2401, 'acceptance_rate': 34.0}},
#  {'location_info': {'lat': 39.4667025, 'lng': -87.4139119, 'state': 'Indiana'},
#   'school': 'Rose-Hulman Institute of Technology',
#   'link': 'www.rose-hulman.edu',
#   'salary_info': {'mid_career_median_salary': 135800.0,
#    'rank': 110,
#    'code': 'IN'},
#   'score_info': {'SAT Lower': 1260.0, 'SAT Upper': 1450.0},
#   'admissions_info': {'students': 2254, 'acceptance_rate': 61.0}},
#  {'location_info': {'lat': 40.0198335,
#    'lng': -75.30462990000002,
#    'state': 'Pennsylvania'},
#   'school': 'Bryn Mawr College',
#   'link': 'www.brynmawr.edu',
#   'salary_info': {'mid_career_median_salary': 95300.0,
#    'rank': 111,
#    'code': 'PA'},
#   'score_info': {'SAT Lower': 1310.0, 'SAT Upper': 1500.0},
#   'admissions_info': {'students': 1640, 'acceptance_rate': 38.0}},
#  {'location_info': {'lat': 41.8239891,
#    'lng': -71.4128343,
#    'state': 'Rhode Island'},
#   'school': 'Rhode Island School of Design',
#   'link': 'www.risd.edu',
#   'salary_info': {'mid_career_median_salary': 100600.0,
#    'rank': 112,
#    'code': 'RI'},
#   'score_info': {'SAT Lower': 1130.0, 'SAT Upper': 1370.0},
#   'admissions_info': {'students': 2440, 'acceptance_rate': 32.0}},
#  {'location_info': {'lat': 40.74025570000001,
#    'lng': -74.0055355,
#    'state': 'New York'},
#   'school': 'Rensselaer Polytechnic Institute',
#   'link': 'www.rpi.edu',
#   'salary_info': {'mid_career_median_salary': 134100.0,
#    'rank': 113,
#    'code': 'NY'},
#   'score_info': {'SAT Lower': 1320.0, 'SAT Upper': 1500.0},
#   'admissions_info': {'students': 7592, 'acceptance_rate': 43.0}},
#  {'location_info': {'lat': 35.35402089999999,
#    'lng': -120.3757163,
#    'state': 'California'},
#   'school': 'California Polytechnic State University, San Luis Obispo',
#   'link': 'calpoly.edu',
#   'salary_info': {'mid_career_median_salary': 119500.0,
#    'rank': 115,
#    'code': 'CA'},
#   'score_info': {'SAT Lower': 1200.0, 'SAT Upper': 1380.0},
#   'admissions_info': {'students': 22370, 'acceptance_rate': 35.0}},
#  {'location_info': {'lat': 44.4582041,
#    'lng': -93.161159,
#    'state': 'Minnesota'},
#   'school': 'St. Olaf College',
#   'link': 'wp.stolaf.edu',
#   'salary_info': {'mid_career_median_salary': 101900.0,
#    'rank': 116,
#    'code': 'MN'},
#   'score_info': {'SAT Lower': 1150.0, 'SAT Upper': 1400.0},
#   'admissions_info': {'students': 3137, 'acceptance_rate': 43.0}},
#  {'location_info': {'lat': 40.7944504,
#    'lng': -77.86163859999998,
#    'state': 'Pennsylvania'},
#   'school': 'Pennsylvania State University',
#   'link': 'www.psu.edu',
#   'salary_info': {'mid_career_median_salary': 105500.0,
#    'rank': 117,
#    'code': 'PA'},
#   'score_info': {'SAT Lower': 1160.0, 'SAT Upper': 1340.0},
#   'admissions_info': {'students': 47119, 'acceptance_rate': 50.0}},
#  {'location_info': {'lat': 40.4258686, 'lng': -86.9080655, 'state': 'Indiana'},
#   'school': 'Purdue University',
#   'link': 'www.purdue.edu',
#   'salary_info': {'mid_career_median_salary': 110000.0,
#    'rank': 118,
#    'code': 'IN'},
#   'score_info': {'SAT Lower': 1150.0, 'SAT Upper': 1380.0},
#   'admissions_info': {'students': 42699, 'acceptance_rate': 57.0}},
#  {'location_info': {'lat': 39.9622601,
#    'lng': -83.00070649999998,
#    'state': 'Ohio'},
#   'school': 'Ohio State University',
#   'link': 'www.osu.edu',
#   'salary_info': {'mid_career_median_salary': 98600.0,
#    'rank': 121,
#    'code': 'OH'},
#   'score_info': {'SAT Lower': 1260.0, 'SAT Upper': 1450.0},
#   'admissions_info': {'students': 59837, 'acceptance_rate': 48.0}},
#  {'location_info': {'lat': 41.8646959,
#    'lng': -88.1101709,
#    'state': 'Illinois'},
#   'school': 'Wheaton College (IL)',
#   'link': 'www.wheaton.edu',
#   'salary_info': {'mid_career_median_salary': 99700.0,
#    'rank': 122,
#    'code': 'IL'},
#   'score_info': {'SAT Lower': 1230.0, 'SAT Upper': 1410.0},
#   'admissions_info': {'students': 2900, 'acceptance_rate': 85.0}},
#  {'location_info': {'lat': 34.0536909,
#    'lng': -118.242766,
#    'state': 'California'},
#   'school': 'Loyola Marymount University',
#   'link': 'www.lmu.edu',
#   'salary_info': {'mid_career_median_salary': 113300.0,
#    'rank': 124,
#    'code': 'CA'},
#   'score_info': {'SAT Lower': 1180.0, 'SAT Upper': 1360.0},
#   'admissions_info': {'students': 9618, 'acceptance_rate': 52.0}},
#  {'location_info': {'lat': 45.5202471, 'lng': -122.6741949, 'state': 'Oregon'},
#   'school': 'University of Portland',
#   'link': 'www.up.edu',
#   'salary_info': {'mid_career_median_salary': 104900.0,
#    'rank': 125,
#    'code': 'OR'},
#   'score_info': {'SAT Lower': 1140.0, 'SAT Upper': 1320.0},
#   'admissions_info': {'students': 4396, 'acceptance_rate': 70.0}},
#  {'location_info': {'lat': 38.8949924,
#    'lng': -77.0365581,
#    'state': 'District of Columbia'},
#   'school': 'American University',
#   'link': 'www.american.edu',
#   'salary_info': {'mid_career_median_salary': 102900.0,
#    'rank': 126,
#    'code': 'DC'},
#   'score_info': {'SAT Lower': 1180.0, 'SAT Upper': 1350.0},
#   'admissions_info': {'students': 13858, 'acceptance_rate': 29.0}},
#  {'location_info': {'lat': 34.851354,
#    'lng': -82.3984882,
#    'state': 'South Carolina'},
#   'school': 'Furman University',
#   'link': 'www2.furman.edu/Pages/default.aspx',
#   'salary_info': {'mid_career_median_salary': 98800.0,
#    'rank': 127,
#    'code': 'SC'},
#   'score_info': {'SAT Lower': 1190.0, 'SAT Upper': 1380.0},
#   'admissions_info': {'students': 2949, 'acceptance_rate': 61.0}},
#  {'location_info': {'lat': 34.035591,
#    'lng': -118.689423,
#    'state': 'California'},
#   'school': 'Pepperdine University',
#   'link': 'www.pepperdine.edu',
#   'salary_info': {'mid_career_median_salary': 103900.0,
#    'rank': 129,
#    'code': 'CA'},
#   'score_info': {'SAT Lower': 1200.0, 'SAT Upper': 1390.0},
#   'admissions_info': {'students': 7710, 'acceptance_rate': 40.0}},
#  {'location_info': {'lat': 41.8084314,
#    'lng': -72.24952309999998,
#    'state': 'Connecticut'},
#   'school': 'University of Connecticut',
#   'link': 'www.uconn.edu',
#   'salary_info': {'mid_career_median_salary': 105200.0,
#    'rank': 130,
#    'code': 'CT'},
#   'score_info': {'SAT Lower': 1210.0, 'SAT Upper': 1390.0},
#   'admissions_info': {'students': 27578, 'acceptance_rate': 48.0}},
#  {'location_info': {'lat': 39.1670396, 'lng': -86.5342881, 'state': 'Indiana'},
#   'school': 'Indiana University, Bloomington',
#   'link': 'www.indiana.edu',
#   'salary_info': {'mid_career_median_salary': 97100.0,
#    'rank': 131,
#    'code': 'IN'},
#   'score_info': {'SAT Lower': 1140.0, 'SAT Upper': 1350.0},
#   'admissions_info': {'students': 43710, 'acceptance_rate': 76.0}},
#  {'location_info': {'lat': 39.6444898, 'lng': -86.8647316, 'state': 'Indiana'},
#   'school': 'DePauw University',
#   'link': 'www.depauw.edu',
#   'salary_info': {'mid_career_median_salary': 101000.0,
#    'rank': 132,
#    'code': 'IN'},
#   'score_info': {'SAT Lower': 1110.0, 'SAT Upper': 1330.0},
#   'admissions_info': {'students': 2253, 'acceptance_rate': 67.0}},
#  {'location_info': {'lat': 36.1029132,
#    'lng': -79.50668950000002,
#    'state': 'North Carolina'},
#   'school': 'Elon University',
#   'link': 'www.elon.edu',
#   'salary_info': {'mid_career_median_salary': 93700.0,
#    'rank': 133,
#    'code': 'NC'},
#   'score_info': {'SAT Lower': 1140.0, 'SAT Upper': 1330.0},
#   'admissions_info': {'students': 6791, 'acceptance_rate': 67.0}},
#  {'location_info': {'lat': 34.685074900000004,
#    'lng': -82.83641109999998,
#    'state': 'South Carolina'},
#   'school': 'Clemson University',
#   'link': 'www.clemson.edu',
#   'salary_info': {'mid_career_median_salary': 106700.0,
#    'rank': 134,
#    'code': 'SC'},
#   'score_info': {'SAT Lower': 1220.0, 'SAT Upper': 1390.0},
#   'admissions_info': {'students': 24387, 'acceptance_rate': 47.0}},
#  {'location_info': {'lat': 38.4493315,
#    'lng': -78.8688833,
#    'state': 'Virginia'},
#   'school': 'James Madison University',
#   'link': 'www.jmu.edu',
#   'salary_info': {'mid_career_median_salary': 102600.0,
#    'rank': 136,
#    'code': 'VA'},
#   'score_info': {'SAT Lower': 1100.0, 'SAT Upper': 1260.0},
#   'admissions_info': {'students': 21836, 'acceptance_rate': 75.0}},
#  {'location_info': {'lat': 42.2495463,
#    'lng': -72.582258,
#    'state': 'Massachusetts'},
#   'school': 'Mount Holyoke College',
#   'link': 'www.mtholyoke.edu',
#   'salary_info': {'mid_career_median_salary': 92100.0,
#    'rank': 137,
#    'code': 'MA'},
#   'score_info': {'SAT Lower': 1270.0, 'SAT Upper': 1463.0},
#   'admissions_info': {'students': 2393, 'acceptance_rate': 51.0}},
#  {'location_info': {'lat': 35.7803977,
#    'lng': -78.63909890000002,
#    'state': 'North Carolina'},
#   'school': 'North Carolina State University, Raleigh',
#   'link': 'www.ncsu.edu',
#   'salary_info': {'mid_career_median_salary': 106500.0,
#    'rank': 139,
#    'code': 'NC'},
#   'score_info': {'SAT Lower': 1230.0, 'SAT Upper': 1390.0},
#   'admissions_info': {'students': 34432, 'acceptance_rate': 51.0}},
#  {'location_info': {'lat': 39.7392364,
#    'lng': -104.9848623,
#    'state': 'Colorado'},
#   'school': 'University of Denver',
#   'link': 'www.du.edu',
#   'salary_info': {'mid_career_median_salary': 105100.0,
#    'rank': 140,
#    'code': 'CO'},
#   'score_info': {'SAT Lower': 1160.0, 'SAT Upper': 1350.0},
#   'admissions_info': {'students': 11434, 'acceptance_rate': 58.0}},
#  {'location_info': {'lat': 40.8466508,
#    'lng': -73.87859370000002,
#    'state': 'New York'},
#   'school': 'Fordham University',
#   'link': 'www.fordham.edu',
#   'salary_info': {'mid_career_median_salary': 112500.0,
#    'rank': 141,
#    'code': 'NY'},
#   'score_info': {'SAT Lower': 1230.0, 'SAT Upper': 1410.0},
#   'admissions_info': {'students': 16037, 'acceptance_rate': 46.0}},
#  {'location_info': {'lat': 32.7174202,
#    'lng': -117.16277279999998,
#    'state': 'California'},
#   'school': 'University of San Diego',
#   'link': 'www.sandiego.edu',
#   'salary_info': {'mid_career_median_salary': 109400.0,
#    'rank': 142,
#    'code': 'CA'},
#   'score_info': {'SAT Lower': 1180.0, 'SAT Upper': 1350.0},
#   'admissions_info': {'students': 8905, 'acceptance_rate': 50.0}},
#  {'location_info': {'lat': 29.4246002, 'lng': -98.4951405, 'state': 'Texas'},
#   'school': 'Trinity University (TX)',
#   'link': 'web.trinity.edu',
#   'salary_info': {'mid_career_median_salary': 102900.0,
#    'rank': 143,
#    'code': 'TX'},
#   'score_info': {'SAT Lower': 1230.0, 'SAT Upper': 1410.0},
#   'admissions_info': {'students': 2571, 'acceptance_rate': 38.0}},
#  {'location_info': {'lat': 40.4416941,
#    'lng': -79.99008609999998,
#    'state': 'Pennsylvania'},
#   'school': 'University of Pittsburgh',
#   'link': 'www.pitt.edu',
#   'salary_info': {'mid_career_median_salary': 100400.0,
#    'rank': 144,
#    'code': 'PA'},
#   'score_info': {'SAT Lower': 1240.0, 'SAT Upper': 1418.0},
#   'admissions_info': {'students': 28642, 'acceptance_rate': 60.0}},
#  {'location_info': {'lat': 42.096968,
#    'lng': -75.91434100000002,
#    'state': 'New York'},
#   'school': 'Binghamton University, SUNY',
#   'link': 'www.binghamton.edu',
#   'salary_info': {'mid_career_median_salary': 109600.0,
#    'rank': 145,
#    'code': 'NY'},
#   'score_info': {'SAT Lower': 1290.0, 'SAT Upper': 1431.0},
#   'admissions_info': {'students': 17351, 'acceptance_rate': 40.0}},
#  {'location_info': {'lat': 40.0149856,
#    'lng': -105.2705456,
#    'state': 'Colorado'},
#   'school': 'University of Colorado, Boulder',
#   'link': 'www.colorado.edu',
#   'salary_info': {'mid_career_median_salary': 109900.0,
#    'rank': 146,
#    'code': 'CO'},
#   'score_info': {'SAT Lower': 1150.0, 'SAT Upper': 1340.0},
#   'admissions_info': {'students': 35338, 'acceptance_rate': 80.0}},
#  {'location_info': {'lat': 39.6852191,
#    'lng': -75.75082890000002,
#    'state': 'Delaware'},
#   'school': 'University of Delaware',
#   'link': 'www.udel.edu',
#   'salary_info': {'mid_career_median_salary': 105400.0,
#    'rank': 147,
#    'code': 'DE'},
#   'score_info': {'SAT Lower': 1130.0, 'SAT Upper': 1330.0},
#   'admissions_info': {'students': 23774, 'acceptance_rate': 63.0}},
#  {'location_info': {'lat': 32.753177, 'lng': -97.3327459, 'state': 'Texas'},
#   'school': 'Texas Christian University',
#   'link': 'www.tcu.edu',
#   'salary_info': {'mid_career_median_salary': 98700.0,
#    'rank': 148,
#    'code': 'TX'},
#   'score_info': {'SAT Lower': 1130.0, 'SAT Upper': 1330.0},
#   'admissions_info': {'students': 10489, 'acceptance_rate': 41.0}},
#  {'location_info': {'lat': 35.1490215,
#    'lng': -90.0516285,
#    'state': 'Tennessee'},
#   'school': 'Rhodes College',
#   'link': 'www.rhodes.edu',
#   'salary_info': {'mid_career_median_salary': 97800.0,
#    'rank': 150,
#    'code': 'TN'},
#   'score_info': {'SAT Lower': 1220.0, 'SAT Upper': 1410.0},
#   'admissions_info': {'students': 2102, 'acceptance_rate': 51.0}},
#  {'location_info': {'lat': 30.4380832, 'lng': -84.2809332, 'state': 'Florida'},
#   'school': 'Florida State University',
#   'link': 'www.fsu.edu',
# ...
#   'admissions_info': {'students': 2257, 'acceptance_rate': 81.0}},
#  {'location_info': {'lat': 42.5006217, 'lng': -90.6647967, 'state': 'Iowa'},
#   'school': 'Clarke University',
#   'link': 'www.clarke.edu',
#   'salary_info': {'mid_career_median_salary': 80200.0,
#    'rank': 594,
#    'code': 'IA'},
#   'score_info': {'SAT Lower': 970.0, 'SAT Upper': 1148.0},
#   'admissions_info': {'students': 1039, 'acceptance_rate': 63.0}},
#  {'location_info': {'lat': 42.5846773,
#    'lng': -87.82122629999998,
#    'state': 'Wisconsin'},
#   'school': 'Carthage College',
#   'link': 'www.carthage.edu',
#   'salary_info': {'mid_career_median_salary': 85400.0,
#    'rank': 595,
#    'code': 'WI'},
#   'score_info': {'SAT Lower': 1040.0, 'SAT Upper': 1300.0},
#   'admissions_info': {'students': 2940, 'acceptance_rate': 68.0}},
#  {'location_info': {'lat': 32.5221828,
#    'lng': -93.7651944,
#    'state': 'Louisiana'},
#   'school': 'Centenary College of Louisiana',
#   'link': 'www.centenary.edu',
#   'salary_info': {'mid_career_median_salary': 88400.0,
#    'rank': 596,
#    'code': 'LA'},
#   'score_info': {'SAT Lower': 1030.0, 'SAT Upper': 1210.0},
#   'admissions_info': {'students': 588, 'acceptance_rate': 62.0}},
#  {'location_info': {'lat': 37.6922361, 'lng': -97.3375448, 'state': 'Kansas'},
#   'school': 'Wichita State University',
#   'link': 'www.wichita.edu',
#   'salary_info': {'mid_career_median_salary': 87300.0,
#    'rank': 597,
#    'code': 'KS'},
#   'score_info': {'SAT Lower': 1000.0, 'SAT Upper': 1275.0},
#   'admissions_info': {'students': 15075, 'acceptance_rate': 94.0}},
#  {'location_info': {'lat': 41.7571701,
#    'lng': -88.31475390000001,
#    'state': 'Illinois'},
#   'school': 'Aurora University',
#   'link': 'www.aurora.edu',
#   'salary_info': {'mid_career_median_salary': 83400.0,
#    'rank': 598,
#    'code': 'IL'},
#   'score_info': {'SAT Lower': 950.0, 'SAT Upper': 1130.0},
#   'admissions_info': {'students': 5833, 'acceptance_rate': 87.0}},
#  {'location_info': {'lat': 36.9903199,
#    'lng': -86.4436018,
#    'state': 'Kentucky'},
#   'school': 'Western Kentucky University',
#   'link': 'www.wku.edu',
#   'salary_info': {'mid_career_median_salary': 83100.0,
#    'rank': 600,
#    'code': 'KY'},
#   'score_info': {'SAT Lower': 970.0, 'SAT Upper': 1180.0},
#   'admissions_info': {'students': 21431, 'acceptance_rate': 95.0}},
#  {'location_info': {'lat': 42.3315509,
#    'lng': -83.04664029999998,
#    'state': 'Michigan'},
#   'school': 'Wayne State University',
#   'link': 'www.wayne.edu',
#   'salary_info': {'mid_career_median_salary': 91700.0,
#    'rank': 601,
#    'code': 'MI'},
#   'score_info': {'SAT Lower': 1000.0, 'SAT Upper': 1210.0},
#   'admissions_info': {'students': 27064, 'acceptance_rate': 67.0}},
#  {'location_info': {'lat': 38.64767020000001,
#    'lng': -107.0603126,
#    'state': 'Colorado'},
#   'school': 'Western Colorado University',
#   'link': 'www.western.edu',
#   'salary_info': {'mid_career_median_salary': 81500.0,
#    'rank': 602,
#    'code': 'CO'},
#   'score_info': {'SAT Lower': 990.0, 'SAT Upper': 1200.0},
#   'admissions_info': {'students': 3343, 'acceptance_rate': 86.0}},
#  {'location_info': {'lat': 41.8239891,
#    'lng': -71.4128343,
#    'state': 'Rhode Island'},
#   'school': 'Rhode Island College',
#   'link': 'www.ric.edu',
#   'salary_info': {'mid_career_median_salary': 83500.0,
#    'rank': 603,
#    'code': 'RI'},
#   'score_info': {'SAT Lower': 880.0, 'SAT Upper': 1090.0},
#   'admissions_info': {'students': 8318, 'acceptance_rate': 74.0}},
#  {'location_info': {'lat': 36.0998131,
#    'lng': -80.2440518,
#    'state': 'North Carolina'},
#   'school': 'Salem College',
#   'link': 'www.salem.edu',
#   'salary_info': {'mid_career_median_salary': 73700.0,
#    'rank': 605,
#    'code': 'NC'},
#   'score_info': {'SAT Lower': 1020.0, 'SAT Upper': 1300.0},
#   'admissions_info': {'students': 984, 'acceptance_rate': 57.0}},
#  {'location_info': {'lat': 31.7754152, 'lng': -106.464634, 'state': 'Texas'},
#   'school': 'University of Texas, El Paso',
#   'link': 'www.utep.edu',
#   'salary_info': {'mid_career_median_salary': 92100.0,
#    'rank': 606,
#    'code': 'TX'},
#   'score_info': {'SAT Lower': 920.0, 'SAT Upper': 1130.0},
#   'admissions_info': {'students': 25078, 'acceptance_rate': 100.0}},
#  {'location_info': {'lat': 38.1352892,
#    'lng': -79.0626247,
#    'state': 'Virginia'},
#   'school': 'Sweet Briar College',
#   'link': 'www.sbc.edu',
#   'salary_info': {'mid_career_median_salary': 79700.0,
#    'rank': 608,
#    'code': 'VA'},
#   'score_info': {'SAT Lower': 993.0, 'SAT Upper': 1180.0},
#   'admissions_info': {'students': 406, 'acceptance_rate': 93.0}},
#  {'location_info': {'lat': 41.6529143, 'lng': -83.5378173, 'state': 'Ohio'},
#   'school': 'University of Toledo',
#   'link': 'www.utoledo.edu',
#   'salary_info': {'mid_career_median_salary': 92500.0,
#    'rank': 609,
#    'code': 'OH'},
#   'score_info': {'SAT Lower': 1020.0, 'SAT Upper': 1240.0},
#   'admissions_info': {'students': 20579, 'acceptance_rate': 94.0}},
#  {'location_info': {'lat': 46.8701049,
#    'lng': -113.9952672,
#    'state': 'Montana'},
#   'school': 'University of Montana',
#   'link': 'www.umt.edu',
#   'salary_info': {'mid_career_median_salary': 87800.0,
#    'rank': 610,
#    'code': 'MT'},
#   'score_info': {'SAT Lower': 1060.0, 'SAT Upper': 1270.0},
#   'admissions_info': {'students': 11865, 'acceptance_rate': 93.0}},
#  {'location_info': {'lat': 30.6943566,
#    'lng': -88.04305409999998,
#    'state': 'Alabama'},
#   'school': 'University of South Alabama',
#   'link': 'www.southalabama.edu',
#   'salary_info': {'mid_career_median_salary': 86400.0,
#    'rank': 612,
#    'code': 'AL'},
#   'score_info': {'SAT Lower': 1010.0, 'SAT Upper': 1200.0},
#   'admissions_info': {'students': 15569, 'acceptance_rate': 82.0}},
#  {'location_info': {'lat': 36.6103334, 'lng': -88.314761, 'state': 'Kentucky'},
#   'school': 'Murray State University',
#   'link': 'www.murraystate.edu',
#   'salary_info': {'mid_career_median_salary': 79900.0,
#    'rank': 613,
#    'code': 'KY'},
#   'score_info': {'SAT Lower': 980.0, 'SAT Upper': 1190.0},
#   'admissions_info': {'students': 10012, 'acceptance_rate': 87.0}},
#  {'location_info': {'lat': 40.1053196, 'lng': -85.6802541, 'state': 'Indiana'},
#   'school': 'Anderson University (IN)',
#   'link': 'anderson.edu',
#   'salary_info': {'mid_career_median_salary': 78600.0,
#    'rank': 614,
#    'code': 'IN'},
#   'score_info': {'SAT Lower': 910.0, 'SAT Upper': 1110.0},
#   'admissions_info': {'students': 1961, 'acceptance_rate': 65.0}},
#  {'location_info': {'lat': 30.421309, 'lng': -87.2169149, 'state': 'Florida'},
#   'school': 'University of West Florida',
#   'link': 'www.uwf.edu',
#   'salary_info': {'mid_career_median_salary': 81700.0,
#    'rank': 615,
#    'code': 'FL'},
#   'score_info': {'SAT Lower': 1080.0, 'SAT Upper': 1240.0},
#   'admissions_info': {'students': 13040, 'acceptance_rate': 50.0}},
#  {'location_info': {'lat': 29.949932300000004,
#    'lng': -90.0701156,
#    'state': 'Louisiana'},
#   'school': 'University of New Orleans',
#   'link': 'www.uno.edu',
#   'salary_info': {'mid_career_median_salary': 91600.0,
#    'rank': 616,
#    'code': 'LA'},
#   'score_info': {'SAT Lower': 1030.0, 'SAT Upper': 1250.0},
#   'admissions_info': {'students': 8082, 'acceptance_rate': 57.0}},
#  {'location_info': {'lat': 40.62145510000001,
#    'lng': -79.1525349,
#    'state': 'Pennsylvania'},
#   'school': 'Indiana University of Pennsylvania',
#   'link': 'www.iup.edu',
#   'salary_info': {'mid_career_median_salary': 85900.0,
#    'rank': 617,
#    'code': 'PA'},
#   'score_info': {'SAT Lower': 910.0, 'SAT Upper': 1120.0},
#   'admissions_info': {'students': 12431, 'acceptance_rate': 91.0}},
#  {'location_info': {'lat': 29.4246002, 'lng': -98.4951405, 'state': 'Texas'},
#   'school': 'University of Texas at San Antonio',
#   'link': 'www.utsa.edu',
#   'salary_info': {'mid_career_median_salary': 87500.0,
#    'rank': 619,
#    'code': 'TX'},
#   'score_info': {'SAT Lower': 1030.0, 'SAT Upper': 1210.0},
#   'admissions_info': {'students': 30768, 'acceptance_rate': 79.0}},
#  {'location_info': {'lat': 39.8454163,
#    'lng': -88.9524151,
#    'state': 'Illinois'},
#   'school': 'Millikin University',
#   'link': 'www.millikin.edu/Pages/default.aspx',
#   'salary_info': {'mid_career_median_salary': 83400.0,
#    'rank': 620,
#    'code': 'IL'},
#   'score_info': {'SAT Lower': 1080.0, 'SAT Upper': 1260.0},
#   'admissions_info': {'students': 2132, 'acceptance_rate': 65.0}},
#  {'location_info': {'lat': 41.5051613, 'lng': -81.6934446, 'state': 'Ohio'},
#   'school': 'Cleveland State University',
#   'link': 'www.csuohio.edu',
#   'salary_info': {'mid_career_median_salary': 88600.0,
#    'rank': 622,
#    'code': 'OH'},
#   'score_info': {'SAT Lower': 990.0, 'SAT Upper': 1210.0},
#   'admissions_info': {'students': 16371, 'acceptance_rate': 90.0}},
#  {'location_info': {'lat': 40.866517,
#    'lng': -124.08284,
#    'state': 'California'},
#   'school': 'Humboldt State University',
#   'link': 'www.humboldt.edu',
#   'salary_info': {'mid_career_median_salary': 89000.0,
#    'rank': 623,
#    'code': 'CA'},
#   'score_info': {'SAT Lower': 960.0, 'SAT Upper': 1160.0},
#   'admissions_info': {'students': 8602, 'acceptance_rate': 82.0}},
#  {'location_info': {'lat': 40.91271029999999,
#    'lng': -90.6472477,
#    'state': 'Illinois'},
#   'school': 'Monmouth College',
#   'link': 'www.monmouthcollege.edu',
#   'salary_info': {'mid_career_median_salary': 88100.0,
#    'rank': 624,
#    'code': 'IL'},
#   'score_info': {'SAT Lower': 900.0, 'SAT Upper': 1090.0},
#   'admissions_info': {'students': 1205, 'acceptance_rate': 67.0}},
#  {'location_info': {'lat': 40.6501024,
#    'lng': -73.9495829,
#    'state': 'New York'},
#   'school': 'St. Francis College',
#   'link': 'www.sfc.edu',
#   'salary_info': {'mid_career_median_salary': 93200.0,
#    'rank': 625,
#    'code': 'NY'},
#   'score_info': {'SAT Lower': 950.0, 'SAT Upper': 1120.0},
#   'admissions_info': {'students': 2745, 'acceptance_rate': 63.0}},
#  {'location_info': {'lat': 37.7274692, 'lng': -89.216655, 'state': 'Illinois'},
#   'school': 'Southern Illinois University Carbondale',
#   'link': 'www.siu.edu',
#   'salary_info': {'mid_career_median_salary': 90900.0,
#    'rank': 629,
#    'code': 'IL'},
#   'score_info': {'SAT Lower': 920.0, 'SAT Upper': 1330.0},
#   'admissions_info': {'students': 14554, 'acceptance_rate': 76.0}},
#  {'location_info': {'lat': 41.1536674, 'lng': -81.357886, 'state': 'Ohio'},
#   'school': 'Kent State University Kent Campus',
#   'link': 'www.kent.edu',
#   'salary_info': {'mid_career_median_salary': 83100.0,
#    'rank': 630,
#    'code': 'OH'},
#   'score_info': {'SAT Lower': 1040.0, 'SAT Upper': 1220.0},
#   'admissions_info': {'students': 28972, 'acceptance_rate': 88.0}},
#  {'location_info': {'lat': 35.845999,
#    'lng': -86.3920452,
#    'state': 'Tennessee'},
#   'school': 'Middle Tennessee State University',
#   'link': 'www.mtsu.edu',
#   'salary_info': {'mid_career_median_salary': 81100.0,
#    'rank': 631,
#    'code': 'TN'},
#   'score_info': {'SAT Lower': 990.0, 'SAT Upper': 1210.0},
#   'admissions_info': {'students': 23050, 'acceptance_rate': 59.0}},
#  {'location_info': {'lat': 35.60094979999999,
#    'lng': -82.5540161,
#    'state': 'North Carolina'},
#   'school': 'Warren Wilson College',
#   'link': 'www.warren-wilson.edu/external_index.php',
#   'salary_info': {'mid_career_median_salary': 74600.0,
#    'rank': 632,
#    'code': 'NC'},
#   'score_info': {'SAT Lower': 1140.0, 'SAT Upper': 1285.0},
#   'admissions_info': {'students': 695, 'acceptance_rate': 79.0}},
#  {'location_info': {'lat': 39.0330902,
#    'lng': -84.4521512,
#    'state': 'Kentucky'},
#   'school': 'Northern Kentucky University',
#   'link': 'www.nku.edu',
#   'salary_info': {'mid_career_median_salary': 87400.0,
#    'rank': 633,
#    'code': 'KY'},
#   'score_info': {'SAT Lower': 993.0, 'SAT Upper': 1210.0},
#   'admissions_info': {'students': 14456, 'acceptance_rate': 90.0}},
#  {'location_info': {'lat': 37.2713951,
#    'lng': -107.8815978,
#    'state': 'Colorado'},
#   'school': 'Fort Lewis College',
#   'link': 'www.fortlewis.edu',
#   'salary_info': {'mid_career_median_salary': 82600.0,
#    'rank': 636,
#    'code': 'CO'},
#   'score_info': {'SAT Lower': 1020.0, 'SAT Upper': 1210.0},
#   'admissions_info': {'students': 3925, 'acceptance_rate': 83.0}},
#  {'location_info': {'lat': 39.7589478, 'lng': -84.1916069, 'state': 'Ohio'},
#   'school': 'Wright State University',
#   'link': 'www.wright.edu',
#   'salary_info': {'mid_career_median_salary': 87800.0,
#    'rank': 638,
#    'code': 'OH'},
#   'score_info': {'SAT Lower': 980.0, 'SAT Upper': 1270.0},
#   'admissions_info': {'students': 15957, 'acceptance_rate': 97.0}},
#  {'location_info': {'lat': 41.312555, 'lng': -81.14371, 'state': 'Ohio'},
#   'school': 'Hiram College',
#   'link': 'www.hiram.edu',
#   'salary_info': {'mid_career_median_salary': 84100.0,
#    'rank': 639,
#    'code': 'OH'},
#   'score_info': {'SAT Lower': 940.0, 'SAT Upper': 1200.0},
#   'admissions_info': {'students': 1221, 'acceptance_rate': 64.0}},
#  {'location_info': {'lat': 35.1490215,
#    'lng': -90.0516285,
#    'state': 'Tennessee'},
#   'school': 'University of Memphis',
#   'link': 'www.mephis.edu',
#   'salary_info': {'mid_career_median_salary': 85800.0,
#    'rank': 640,
#    'code': 'TN'},
#   'score_info': {'SAT Lower': 1010.0, 'SAT Upper': 1230.0},
#   'admissions_info': {'students': 21521, 'acceptance_rate': 85.0}},
#  {'location_info': {'lat': 37.74785720000001,
#    'lng': -84.29465390000001,
#    'state': 'Kentucky'},
#   'school': 'Eastern Kentucky University',
#   'link': 'www.eku.edu',
#   'salary_info': {'mid_career_median_salary': 80700.0,
#    'rank': 641,
#    'code': 'KY'},
#   'score_info': {'SAT Lower': 960.0, 'SAT Upper': 1130.0},
#   'admissions_info': {'students': 16612, 'acceptance_rate': 87.0}},
#  {'location_info': {'lat': 36.1622296,
#    'lng': -86.7743531,
#    'state': 'Tennessee'},
#   'school': 'Fisk University',
#   'link': 'www.fisk.edu/Home.aspx',
#   'salary_info': {'mid_career_median_salary': 83600.0,
#    'rank': 642,
#    'code': 'TN'},
#   'score_info': {'SAT Lower': 940.0, 'SAT Upper': 1260.0},
#   'admissions_info': {'students': 738, 'acceptance_rate': 45.0}},
#  {'location_info': {'lat': 36.122311,
#    'lng': -83.4923961,
#    'state': 'Tennessee'},
#   'school': 'Carson-Newman University',
#   'link': 'www.cn.edu',
#   'salary_info': {'mid_career_median_salary': 76500.0,
#    'rank': 644,
#    'code': 'TN'},
#   'score_info': {'SAT Lower': 940.0, 'SAT Upper': 1150.0},
#   'admissions_info': {'students': 2514, 'acceptance_rate': 67.0}},
#  {'location_info': {'lat': 33.7489924, 'lng': -84.3902644, 'state': 'Georgia'},
#   'school': 'Morehouse College',
#   'link': 'www.morehouse.edu',
#   'salary_info': {'mid_career_median_salary': 98700.0,
#    'rank': 645,
#    'code': 'GA'},
#   'score_info': {'SAT Lower': 950.0, 'SAT Upper': 1160.0},
#   'admissions_info': {'students': 2219, 'acceptance_rate': 74.0}},
#  {'location_info': {'lat': 32.3140354,
#    'lng': -106.7798078,
#    'state': 'New Mexico'},
#   'school': 'New Mexico State University',
#   'link': 'www.nmsu.edu',
#   'salary_info': {'mid_career_median_salary': 96700.0,
#    'rank': 646,
#    'code': 'NM'},
#   'score_info': {'SAT Lower': 910.0, 'SAT Upper': 1160.0},
#   'admissions_info': {'students': 14432, 'acceptance_rate': 64.0}},
#  {'location_info': {'lat': 39.4667025, 'lng': -87.4139119, 'state': 'Indiana'},
#   'school': 'Indiana State University',
#   'link': 'www.indstate.edu',
#   'salary_info': {'mid_career_median_salary': 85600.0,
#    'rank': 647,
#    'code': 'IN'},
#   'score_info': {'SAT Lower': 900.0, 'SAT Upper': 1110.0},
#   'admissions_info': {'students': 13763, 'acceptance_rate': 85.0}},
#  {'location_info': {'lat': 36.7728907,
#    'lng': -81.8362343,
#    'state': 'Virginia'},
#   'school': 'Emory &amp; Henry College',
#   'link': 'www.ehc.edu',
#   'salary_info': {'mid_career_median_salary': 70700.0,
#    'rank': 648,
#    'code': 'VA'},
#   'score_info': {'SAT Lower': 988.0, 'SAT Upper': 1170.0},
#   'admissions_info': {'students': 1226, 'acceptance_rate': 72.0}},
#  {'location_info': {'lat': 35.6709727,
#    'lng': -80.4742261,
#    'state': 'North Carolina'},
#   'school': 'Catawba College',
#   'link': 'www.catawba.edu',
#   'salary_info': {'mid_career_median_salary': 78100.0,
#    'rank': 650,
#    'code': 'NC'},
#   'score_info': {'SAT Lower': 930.0, 'SAT Upper': 1100.0},
#   'admissions_info': {'students': 1463, 'acceptance_rate': 42.0}}]

# %%
with open("UNIVERSITIES.json", 'w') as outfile:
    outfile.write(json.dumps(json_data))
